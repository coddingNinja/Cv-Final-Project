# %% [markdown]
# # Imports

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
import HelperFunction

# %% [markdown]
# # Video Capturing

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)
# Out:
# True

# %% [markdown]
# # Loading Model Weights

# %%
model = YOLO("playingCards.pt")

# %% [markdown]
# # Defining Class Names

# %%
classNames = ['10C', '10D', '10H', '10S',
              '2C', '2D', '2H', '2S',
              '3C', '3D', '3H', '3S',
              '4C', '4D', '4H', '4S',
              '5C', '5D', '5H', '5S',
              '6C', '6D', '6H', '6S',
              '7C', '7D', '7H', '7S',
              '8C', '8D', '8H', '8S',
              '9C', '9D', '9H', '9S',
              'AC', 'AD', 'AH', 'AS',
              'JC', 'JD', 'JH', 'JS',
              'KC', 'KD', 'KH', 'KS',
              'QC', 'QD', 'QH', 'QS']

# %% [markdown]
# # Detections

# %%
while True:
    success, img = cap.read()
    results = model(img, stream=True)
    hand = []

    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1

            cvzone.cornerRect(img, (x1, y1, w, h))

            conf = math.ceil(box.conf[0] * 100) / 100

            cls = int(box.cls[0])

            cvzone.putTextRect(img, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)
            
            if conf > 0.5:
                hand.append(classNames[cls])
    
    hand = list(set(hand))

    if len(hand) == 5:
        results = HelperFunction.findPokerHand(hand)
        cvzone.putTextRect(img, f'Your Hand: {results}', (300, 75), scale=3, thickness=5)

    cv2.imshow("Image", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# 0: 384x640 (no detections), 403.7ms
# Speed: 5.9ms preprocess, 403.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 802.1ms
# Speed: 5.1ms preprocess, 802.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 480.8ms
# Speed: 2.3ms preprocess, 480.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 473.5ms
# Speed: 1.9ms preprocess, 473.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 490.5ms
# Speed: 6.4ms preprocess, 490.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 409.9ms
# Speed: 2.1ms preprocess, 409.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 361.1ms
# Speed: 1.6ms preprocess, 361.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 375.7ms
# Speed: 4.9ms preprocess, 375.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 376.6ms
# Speed: 2.1ms preprocess, 376.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 354.9ms
# Speed: 4.1ms preprocess, 354.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 403.7ms
# Speed: 4.6ms preprocess, 403.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 376.6ms
# Speed: 1.6ms preprocess, 376.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 367.3ms
# Speed: 1.7ms preprocess, 367.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 396.9ms
# Speed: 5.4ms preprocess, 396.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 367.8ms
# Speed: 3.9ms preprocess, 367.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 384.6ms
# Speed: 4.3ms preprocess, 384.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 384.3ms
# Speed: 1.7ms preprocess, 384.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 370.6ms
# Speed: 4.5ms preprocess, 370.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 427.6ms
# Speed: 2.5ms preprocess, 427.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 377.5ms
# Speed: 1.7ms preprocess, 377.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 359.2ms
# Speed: 2.9ms preprocess, 359.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 370.6ms
# Speed: 4.7ms preprocess, 370.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 373.6ms
# Speed: 3.6ms preprocess, 373.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 2 2Ss, 1 6D, 367.6ms
# Speed: 3.4ms preprocess, 367.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 375.8ms
# Speed: 4.4ms preprocess, 375.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 2 2Ss, 1 6D, 377.9ms
# Speed: 4.2ms preprocess, 377.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 2Cs, 1 2D, 1 2S, 1 6D, 407.2ms
# Speed: 18.0ms preprocess, 407.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 373.9ms
# Speed: 3.4ms preprocess, 373.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 351.9ms
# Speed: 3.0ms preprocess, 351.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 373.3ms
# Speed: 3.1ms preprocess, 373.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 2 2Ss, 1 6D, 400.2ms
# Speed: 3.1ms preprocess, 400.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 374.8ms
# Speed: 3.1ms preprocess, 374.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 440.3ms
# Speed: 4.4ms preprocess, 440.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 369.0ms
# Speed: 1.6ms preprocess, 369.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 346.4ms
# Speed: 1.5ms preprocess, 346.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 402.5ms
# Speed: 39.1ms preprocess, 402.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 308.9ms
# Speed: 3.6ms preprocess, 308.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 315.9ms
# Speed: 1.6ms preprocess, 315.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 6D, 308.4ms
# Speed: 4.0ms preprocess, 308.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2S, 1 5D, 1 7D, 309.1ms
# Speed: 2.6ms preprocess, 309.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 335.4ms
# Speed: 1.7ms preprocess, 335.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 331.9ms
# Speed: 5.0ms preprocess, 331.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 311.7ms
# Speed: 4.1ms preprocess, 311.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 425.4ms
# Speed: 4.8ms preprocess, 425.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 308.0ms
# Speed: 1.6ms preprocess, 308.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 313.9ms
# Speed: 4.1ms preprocess, 313.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 317.1ms
# Speed: 3.5ms preprocess, 317.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 312.5ms
# Speed: 2.6ms preprocess, 312.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 307.6ms
# Speed: 2.6ms preprocess, 307.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 305.2ms
# Speed: 4.1ms preprocess, 305.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 309.8ms
# Speed: 1.6ms preprocess, 309.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 419.2ms
# Speed: 1.5ms preprocess, 419.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 296.0ms
# Speed: 5.2ms preprocess, 296.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 318.1ms
# Speed: 1.5ms preprocess, 318.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 2 6Ds, 324.1ms
# Speed: 1.7ms preprocess, 324.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 2 6Ds, 316.7ms
# Speed: 4.2ms preprocess, 316.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 2 6Ds, 304.3ms
# Speed: 1.6ms preprocess, 304.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 2 6Ds, 313.9ms
# Speed: 3.8ms preprocess, 313.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 2 6Ds, 438.1ms
# Speed: 4.0ms preprocess, 438.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 1 2C, 1 2D, 1 2H, 1 2S, 2 6Ds, 311.2ms
# Speed: 2.2ms preprocess, 311.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ['2C', '2H', '2S', '6D', '2D'] Four of a Kind
#
# 0: 384x640 2 6Ds, 308.3ms
# Speed: 1.5ms preprocess, 308.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 312.3ms
# Speed: 1.6ms preprocess, 312.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 318.9ms
# Speed: 3.0ms preprocess, 318.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 317.8ms
# Speed: 2.4ms preprocess, 317.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 316.8ms
# Speed: 1.5ms preprocess, 316.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 333.0ms
# Speed: 3.2ms preprocess, 333.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 452.7ms
# Speed: 2.3ms preprocess, 452.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 319.4ms
# Speed: 1.9ms preprocess, 319.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 304.2ms
# Speed: 1.6ms preprocess, 304.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 309.4ms
# Speed: 1.7ms preprocess, 309.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 318.3ms
# Speed: 1.6ms preprocess, 318.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
