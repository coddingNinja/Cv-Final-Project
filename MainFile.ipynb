# %% [markdown]
# # Imports

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
import HelperFunction

# %% [markdown]
# # Video Capturing

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)
# Out:
# 2025-12-15 21:51:35.041 python[60454:1971775] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# True

# %% [markdown]
# # Loading Model Weights

# %%
model = YOLO("playingCards.pt")

# %% [markdown]
# # Defining Class Names

# %%
classNames = ['10C', '10D', '10H', '10S',
              '2C', '2D', '2H', '2S',
              '3C', '3D', '3H', '3S',
              '4C', '4D', '4H', '4S',
              '5C', '5D', '5H', '5S',
              '6C', '6D', '6H', '6S',
              '7C', '7D', '7H', '7S',
              '8C', '8D', '8H', '8S',
              '9C', '9D', '9H', '9S',
              'AC', 'AD', 'AH', 'AS',
              'JC', 'JD', 'JH', 'JS',
              'KC', 'KD', 'KH', 'KS',
              'QC', 'QD', 'QH', 'QS']

# %% [markdown]
# # Detections

# %%
while True:
    success, img = cap.read()
    results = model(img, stream=True)
    hand = []

    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1

            cvzone.cornerRect(img, (x1, y1, w, h))

            conf = math.ceil(box.conf[0] * 100) / 100

            cls = int(box.cls[0])

            cvzone.putTextRect(img, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)
            
            if conf > 0.5:
                hand.append(classNames[cls])
    
    hand = list(set(hand))

    if len(hand) == 5:
        results = HelperFunction.findPokerHand(hand)
        cvzone.putTextRect(img, f'Your Hand: {results}', (300, 75), scale=3, thickness=5)

    cv2.imshow("Image", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# 0: 384x640 (no detections), 924.6ms
# Speed: 4.2ms preprocess, 924.6ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 686.1ms
# Speed: 5.5ms preprocess, 686.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 537.2ms
# Speed: 1.6ms preprocess, 537.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 519.3ms
# Speed: 1.5ms preprocess, 519.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 524.3ms
# Speed: 2.0ms preprocess, 524.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 527.2ms
# Speed: 1.7ms preprocess, 527.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 519.7ms
# Speed: 1.5ms preprocess, 519.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 511.3ms
# Speed: 1.5ms preprocess, 511.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 510.7ms
# Speed: 1.4ms preprocess, 510.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 545.3ms
# Speed: 1.6ms preprocess, 545.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 513.9ms
# Speed: 1.5ms preprocess, 513.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 511.1ms
# Speed: 1.5ms preprocess, 511.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 509.3ms
# Speed: 1.5ms preprocess, 509.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 518.1ms
# Speed: 1.6ms preprocess, 518.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 521.2ms
# Speed: 1.8ms preprocess, 521.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 550.8ms
# Speed: 1.4ms preprocess, 550.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 565.4ms
# Speed: 1.6ms preprocess, 565.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 622.1ms
# Speed: 2.3ms preprocess, 622.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 534.0ms
# Speed: 1.6ms preprocess, 534.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 513.0ms
# Speed: 1.5ms preprocess, 513.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 655.4ms
# Speed: 1.8ms preprocess, 655.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 631.6ms
# Speed: 2.3ms preprocess, 631.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 544.3ms
# Speed: 1.8ms preprocess, 544.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 571.9ms
# Speed: 1.8ms preprocess, 571.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 540.0ms
# Speed: 2.1ms preprocess, 540.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 539.5ms
# Speed: 1.8ms preprocess, 539.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 600.0ms
# Speed: 1.8ms preprocess, 600.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 587.3ms
# Speed: 2.2ms preprocess, 587.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 523.1ms
# Speed: 1.7ms preprocess, 523.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 535.3ms
# Speed: 1.8ms preprocess, 535.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 513.9ms
# Speed: 1.6ms preprocess, 513.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 506.8ms
# Speed: 1.5ms preprocess, 506.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 508.3ms
# Speed: 1.6ms preprocess, 508.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 506.8ms
# Speed: 1.8ms preprocess, 506.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 532.3ms
# Speed: 1.5ms preprocess, 532.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 545.5ms
# Speed: 1.9ms preprocess, 545.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 518.6ms
# Speed: 1.5ms preprocess, 518.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
